# %%
import pymongo as pg

# %%
connection = pg.MongoClient("mongodb://vinoth:vinothvk@ac-8om7l8w-shard-00-00.srdizaf.mongodb.net:27017,ac-8om7l8w-shard-00-01.srdizaf.mongodb.net:27017,ac-8om7l8w-shard-00-02.srdizaf.mongodb.net:27017/?ssl=true&replicaSet=atlas-1coxpo-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
connection.test
# Out:
# Database(MongoClient(host=['ac-8om7l8w-shard-00-01.srdizaf.mongodb.net:27017', 'ac-8om7l8w-shard-00-02.srdizaf.mongodb.net:27017', 'ac-8om7l8w-shard-00-00.srdizaf.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-1coxpo-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'test')

# %%
connection.list_database_names()
# Out:
# ['guvi',
#  'hotstar',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'vinoth',
#  'youtube_data',
#  'yt_data',
#  'admin',
#  'local']

# %%
db = connection['sample_airbnb']

# %%
db.list_collection_names()
# Out:
# ['listingsAndReviews']

# %%
col = db['listingsAndReviews']

# %%
# Extracting the Data

data = col.find()

data_list = []

for i in data:
    id = i['_id']
    Listing_url = i['listing_url']
    Name = i['name']
    Description = i['description']
    Host_id  = i['host']['host_id']
    Host_name = i['host']['host_name']
    Neighborhood_overview = i['neighborhood_overview']
    Location = i['address']['location']['coordinates']
    Country = i['address']['country']
    City = i['address']['market']
    Price = i['price']
    Availability_30 = i['availability']['availability_30']
    Availability_60 = i['availability']['availability_60']
    Availability_90 = i['availability']['availability_90']
    Availability_365 = i['availability']['availability_365']
    Amenities = i['amenities']
    Review_scores_value = i.get('review_scores', {}).get('review_scores_value', None)
    No_of_reviews = i['number_of_reviews']
    
    Row_data = [id,listing_url,name,description,host_id,host_name,neighborhood_overview,location,country,city,price,availability_30,availability_60,availability_90,availability_365,amenities,no_of_reviews,review_scores_value]
    data_list.append(row_data)

# %%
import pandas as pd

# %%
df = pd.DataFrame(data_list,columns = ['id','listing_url','name','description','host_id','host_name','neighborhood_overview','location','country','city','price','availability_30','availability_60','availability_90','availability_365','amenities','no_of_reviews','review_score'])

# %%
df
# Out:
#             id                            listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name  \
# 0                               Ribeira Charming Duplex
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                              Private Room in Bushwick
# ...

# %% [markdown]
# # Preprocessing Data

# %%
df['latitude'] = df['location'].apply(lambda x:x[1])
df['longitude'] = df['location'].apply(lambda x:x[0])

# %%
df.drop('location',axis = 1,inplace=True)

# %%
df.head()
# Out:
#          id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10030955  https://www.airbnb.com/rooms/10030955
#
#                                name  \
# 0           Ribeira Charming Duplex
# 1      Horto flat with small garden
# 2  Ocean View Waikiki Marina w/prkg
# 3          Private Room in Bushwick
# 4       Apt Linda Vista Lagoa - Rio
#
#                                          description   host_id    host_name  \
# 0  Fantastic duplex apartment with three bedrooms...  51399391  Ana&Gonçalo
# 1  One bedroom + sofa-bed in quiet and bucolic ne...   1282196        Ynaie
# 2  A short distance from Honolulu's billion dolla...   5448114        David
# 3  Here exists a very cozy room for rent in a sha...  11275734         Josh
# ...

# %%
df.to_csv('Extracted.csv',index = False)

# %%
Extracted_data = pd.read_csv('Extracted.csv')
Extracted_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     5555 non-null   int64
#  1   listing_url            5555 non-null   object
#  2   name                   5547 non-null   object
#  3   description            5460 non-null   object
#  4   host_id                5555 non-null   int64
#  5   host_name              5555 non-null   object
#  6   neighborhood_overview  3314 non-null   object
#  7   country                5555 non-null   object
#  8   city                   5549 non-null   object
#  9   price                  5555 non-null   float64
#  10  availability_30        5555 non-null   int64
#  11  availability_60        5555 non-null   int64
#  12  availability_90        5555 non-null   int64
#  13  availability_365       5555 non-null   int64
# ...

# %%
Extracted_data.shape
# Out:
# (5555, 19)

# %%
#null values
Extracted_data.isnull().sum()
# Out:
# id                          0
# listing_url                 0
# name                        8
# description                95
# host_id                     0
# host_name                   0
# neighborhood_overview    2241
# country                     0
# city                        6
# price                       0
# availability_30             0
# availability_60             0
# availability_90             0
# availability_365            0
# amenities                   0
# no_of_reviews               0
# review_score             1475
# latitude                    0
# longitude                   0
# dtype: int64

# %%
# Dropping the null values
Extracted_data.dropna(inplace = True)

# %%
Extracted_data
# Out:
#             id                            listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 5      1003530   https://www.airbnb.com/rooms/1003530
# 6     10038496  https://www.airbnb.com/rooms/10038496
# 7     10047964  https://www.airbnb.com/rooms/10047964
# ...        ...                                    ...
# 5546   9951865   https://www.airbnb.com/rooms/9951865
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name  \
# 0                               Ribeira Charming Duplex
# 2                      Ocean View Waikiki Marina w/prkg
# 5                   New York City - Upper West Side Apt
# 6                          Copacabana Apartment Posto 6
# ...

# %%
# Dropping the neighborhood overview column
Extracted_data.drop('neighborhood_overview',axis = 1,inplace = True)

# %%
Extracted_data.isnull().sum()
# Out:
# id                  0
# listing_url         0
# name                0
# description         0
# host_id             0
# host_name           0
# country             0
# city                0
# price               0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# amenities           0
# no_of_reviews       0
# review_score        0
# latitude            0
# longitude           0
# dtype: int64

# %%
Extracted_data.reset_index(drop=True, inplace = True)
Extracted_data.head()
# Out:
#          id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1   1001265   https://www.airbnb.com/rooms/1001265
# 2   1003530   https://www.airbnb.com/rooms/1003530
# 3  10038496  https://www.airbnb.com/rooms/10038496
# 4  10047964  https://www.airbnb.com/rooms/10047964
#
#                                   name  \
# 0              Ribeira Charming Duplex
# 1     Ocean View Waikiki Marina w/prkg
# 2  New York City - Upper West Side Apt
# 3         Copacabana Apartment Posto 6
# 4       Charming Flat in Downtown Moda
#
#                                          description   host_id    host_name  \
# 0  Fantastic duplex apartment with three bedrooms...  51399391  Ana&Gonçalo
# 1  A short distance from Honolulu's billion dolla...   5448114        David
# 2  Murphy bed, optional second bedroom available....    454250        Greta
# 3  The Apartment has a living room, toilet, bedro...  51530266  Ana Valéria
# ...

# %%
# Exporting the data into csv
Extracted_data.to_csv('Airbnb_Analysis.csv')
